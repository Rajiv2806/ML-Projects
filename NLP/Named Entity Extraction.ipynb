# %% [markdown]
# # Named Entity Extraction using NLTK
#
# requires nltk >3.0
#
# [Data Source - Kaggle](https://www.kaggle.com/shivamb/netflix-shows)

# %%
import nltk
import pandas as pd

# %%
df = pd.read_csv("data/netflix_titles.csv.zip",compression='zip', sep= ',')
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
movie_corpus = " ".join(df.loc[:,'description'])
print(len(movie_corpus))
movie_corpus[:1000]
# Out:
# 1270878
# "As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable. After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth. To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war. Feuds, flirtations and toilet talk go down among the incarcerated women at the Orleans Justice Center in New Orleans on this gritty reality series. In a city of coaching centers known to train India’s finest collegiate minds, an earnest but unexceptional student and his friends navigate campus life. The arrival of a charismatic young priest brings glorious miracles, ominous mysteries and renewed religious fervor to a dying town desperate to believe. Equestria's divided. But a bright-eyed hero believes Earth Ponies, Pegasi and Unicorns should be p"

# %%
sentences = nltk.sent_tokenize(movie_corpus)
print(len(sentences))
sentences[:5]
# Out:
# 9744
# ['As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.',
#  'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.',
#  'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.',
#  'Feuds, flirtations and toilet talk go down among the incarcerated women at the Orleans Justice Center in New Orleans on this gritty reality series.',
#  'In a city of coaching centers known to train India’s finest collegiate minds, an earnest but unexceptional student and his friends navigate campus life.']

# %%
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
print(len(tokenized_sentences))
tokenized_sentences[0]
# Out:
# 9744
# ['As',
#  'her',
#  'father',
#  'nears',
#  'the',
#  'end',
#  'of',
#  'his',
#  'life',
#  ',',
#  'filmmaker',
#  'Kirsten',
#  'Johnson',
#  'stages',
#  'his',
#  'death',
#  'in',
#  'inventive',
#  'and',
#  'comical',
#  'ways',
#  'to',
#  'help',
#  'them',
#  'both',
#  'face',
#  'the',
#  'inevitable',
#  '.']

# %%
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
print(len(tagged_sentences))
tagged_sentences[0]
# Out:
# 9744
# [('As', 'IN'),
#  ('her', 'PRP$'),
#  ('father', 'NN'),
#  ('nears', 'VBZ'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('life', 'NN'),
#  (',', ','),
#  ('filmmaker', 'NN'),
#  ('Kirsten', 'NNP'),
#  ('Johnson', 'NNP'),
#  ('stages', 'VBZ'),
#  ('his', 'PRP$'),
#  ('death', 'NN'),
#  ('in', 'IN'),
#  ('inventive', 'JJ'),
#  ('and', 'CC'),
#  ('comical', 'JJ'),
#  ('ways', 'NNS'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('them', 'PRP'),
#  ('both', 'DT'),
#  ('face', 'VBP'),
#  ('the', 'DT'),
#  ('inevitable', 'JJ'),
#  ('.', '.')]

# %%
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)
# [i for i in chunked_sentences]

# %%
def extract_entity_names(t):
    entity_names = []
    
    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
                
    return entity_names

# %%
# entity_names = [extract_entity_names(tree) for tree in chunked_sentences]
entity_list = [" ".join(i) for i in entity_names if i]
list(set(entity_list))
# Out:
# ['Omar Salma',
#  'Jean Holloway',
#  'Comedian Ryuji Akiyama Japan',
#  'Tom Jerry',
#  'Ryan Hamilton New York Disney World',
#  'Taylor Swift',
#  'Jake Kansas',
#  'Sea',
#  'Haruo Exif',
#  'Celestina',
#  'Rescue Riders',
#  'Catholic France Léon Rivail',
#  'Join Strawberry Shortcake Berry Bitty City',
#  'José Miguel',
#  'Tehran',
#  'Army Mystic Force Power Rangers',
#  'Carson Cory',
#  'Louise Down',
#  'Shrek',
#  'CIA FBI',
#  'Israeli Eli Cohen Syria Mossad',
#  'Calvin',
#  'Robinson',
#  'Europe William',
#  'Bean',
#  'Freed',
#  'Green Destiny',
#  'Sonny Koufax',
#  'Oregon',
#  'Convinced',
#  'U.S. Mississippi',
#  'Steve Harvey Entertainer',
#  'Eternia Teela Universe',
#  'Lorelai Ivy',
#  'Johannesburg',
#  'Kitty Galore',
#  'Young Mexico',
#  'Power Rangers California',
#  'Istanbul Mehmet',
#  'Monty Python Eric Idle British Empire',
#  'Teenage McKeyla',
#  'Quincy Jones',
#  'Eclectic Marco Luque',
#  'Bogotá',
#  'Red Skull Iron Man Captain America',
#  'Air John Cutter Charles Rane Rane',
#  'South African',
#  'Filmmaker Errol Morris',
#  'Tessa Hardin',
#  'Migi',
#  'Lincoln Loud Scotland',
#  'Major Ram Prasad Sharma',
#  'Flint Michigan',
#  'Jeff Winger',
#  'Pope Francis',
#  'Taiwan America',
#  'Ireland',
#  'Princess Diana Queen Elizabeth II Tony Blair',
#  'Scottish Jack',
#  'Earth',
#  'Masha',
#  'Atlanta',
#  'Miami Showband Ireland',
#  'Lizzie Borden',
#  'Tired Johanne',
#  'CRISPR',
#  'Dadá Figueiredo',
#  'Whitney Cummings Washington',
#  'Belgian',
#  'Justin Fashanu',
#  'Barbie',
#  'Andy Samberg',
#  'Aragorn Gandalf Gondor',
#  'Karan Mumbai',
#  'Scotland Bruce English',
#  'Madeleine McCann',
#  'Merlin Camelot',
#  'Rahul Mumbai',
#  'Bangkok Chinatown',
#  'Fred Armisen Carrie Brownstein Portland Ore',
#  'Thrust',
#  'Riza Santa',
#  'Rafał Rutkowski Comedy Lab Olka Szczęśniak Warsaw Klub Hybrydy',
#  'Ahead Kübra',
#  'Toronto Montreal',
#  'Bethany Hamilton',
#  'RuPaul',
#  'Bill Gates',
#  'Kimmy',
#  'Born Ratu India Deepika Kumari',
#  'Asia Don Europe',
#  'Join Turbo Fast Action Stunt Team',
#  'Quadruplets Manila',
#  'Lakewood',
#  'Jason Voorhees',
#  'Port Said Kariman',
#  'Charlie',
#  'Smurfs New York',
#  'Deidra',
#  'Ginger Rosa London',
#  'Berlin',
#  'Magic Sabrina Night',
#  'British New Zealand',
#  'Animosity Patagonia',
#  'Siddharth',
#  'Chelsea Handler American',
#  'Meet Chuck Wepner Rocky Balboa',
#  'Brooklyn',
#  'New York',
#  'Sarah Mindy',
#  'Naruto',
#  'Julie',
#  'Optimus AllSpark',
#  'Maine',
#  'Havana Mario Conde',
#  'John Mulaney',
#  'Sex',
#  'Funnyman Jim Gaffigan Disney World Washington',
#  'Soccer Claudio Tamburrini Argentine',
#  'Tokyo Osaka',
#  'Delve',
#  'Snow White',
#  'Neige',
#  'Spunky',
#  'Comedian Trump',
#  'Eric Andre New Orleans',
#  'Soren',
#  'Great Depression',
#  'Passion',
#  'Christine',
#  'Athenian British Museum Parthenon Marbles Greece',
#  'Fakkah Fuzz Malay Singapore',
#  'Lucknow',
#  'Pacific',
#  'Casino Lebanese Adel Karam Rocco',
#  'Bobbi Jene Smith Israeli Ohad Naharin',
#  'Teenage Brendan Fry',
#  'David Farrier',
#  'Monty Don France',
#  'Teams',
#  'Moanica',
#  'Master Splinter New York',
#  'Torn Roman',
#  'Writer Jon Favreau',
#  'Sylvia Earle',
#  'Tara U.S.',
#  'Western',
#  'Amidst',
#  'Sarajevo',
#  'Ash Alola Pokémon',
#  'David Brent',
#  'Mohammad Azharuddin India',
#  'San Francisco Mary Ann Singleton',
#  'Olive',
#  'Jim Gaffigan Austin',
#  'Indian Western British',
#  'Chef Rick Bayless',
#  'Mithco Sunnytown',
#  'Flintstones Fred Barney',
#  'Emilio Oscar Martínez Alzheimer',
#  'Raj Pirya',
#  'Chakuro',
#  'Cape Town South Africa',
#  'Alliance Academy',
#  'Skullbania',
#  'London Paris',
#  'Elouise Cobell U.S. American',
#  'Rashida Jones',
#  'Beauty Thailand',
#  'John Travolta Olivia',
#  'Affable Galactic Ranger Clank Drek',
#  'Beautiful',
#  'ATM',
#  'African',
#  'Tokyo Dome',
#  'Hawaii Timmy',
#  'Great',
#  'Jurassic World',
#  'Axel LeapFrog Max Numberland',
#  'Iron Fist',
#  'Hit Lehman',
#  'Gorm',
#  'Great Norse Uhtred Vikings',
#  'Eight Dolly Parton',
#  'Comedian Mike Birbiglia Brooklyn',
#  'Zimbabwe',
#  'Christopher Columbus New World Bolivian',
#  'Malaysian Harith Iskander Kuala Lumpur Singapore Rick Astley',
#  'Iraq Afghanistan Pakistan',
#  'Historian Bettany Hughes India Greece China Buddha Socrates Confucius',
#  'Tony Hawk',
#  'Auschwitz',
#  'Colt',
#  'Québec',
#  'Join Lucky Maricela',
#  'Hari Kondabolu',
#  'CNN Christiane Amanpour',
#  'French Real Madrid Karim Benzema',
#  'Glimpse Turkish Metin Akpınar',
#  'Join Jeff Foxworthy',
#  'Germany Nazi Joseph Goebbels',
#  'CIA Ted Kaczynski',
#  'Forbidden Planet Leslie Nielsen',
#  'Nair Indian',
#  'Host Francesca Stavrakopoulou Middle East Old Testament',
#  'Clown',
#  'Brash Gregorio Philippines',
#  'Host RJ Anmol Indian',
#  'Linda Bishop',
#  'English',
#  'Shanghai',
#  'Shivaji',
#  'Los Angeles',
#  'Filosofi Kopi',
#  'Australian Helen Reddy',
#  'Buddhism',
#  'American Ellis India Tamil',
#  'Scottish Western America',
#  'CrossFit Sanctional',
#  'Digital Fred Barney Betty Wilma',
#  'Felix Lobrecht',
#  'Bell Tolls',
#  'ChuChu Chiku ChaCha',
#  'Tracy Morgan',
#  'Chris Norton',
#  'Nazi Kaiser Wilhelm Dutch',
#  'Olympian UFC Ronda Rousey',
#  'Popoy',
#  'Inside',
#  'Sebastian Maniscalco Beacon Theatre Whole Foods',
#  'Ricky Gervais',
#  'American Donald Trump U.S.',
#  'Kaal',
#  'VHS',
#  'United Corporations America',
#  'Hamburg Enissa Amani German',
#  'Southern Ronnie Van Zant',
#  'Catholic',
#  'Hellboy Nazis',
#  'Six Iceland',
#  'Ethan Seymour High',
#  'Roberts Costa Rica Barbie',
#  'Hughley Philadelphia',
#  'Dracula Frankenstein Dorian Gray Victorian London',
#  'Abby',
#  'André Merlaux French Secret Service',
#  'Kath Kel Michael Bublé Kim Sharon Yuletide',
#  'Hulk Marvel Universe',
#  'Nelson Mandela South Africa',
#  'Muhammad Ali Chuck Wepner',
#  'Detroit Rodriguez',
#  'Kayla Mac',
#  'Master Chief Spartan',
#  'Mike Epps',
#  'Sanjay Karina',
#  'Fire Tribe',
#  'Second Impact Shinji Ikari NERV',
#  'Camino Santiago',
#  'Katla',
#  'Junior',
#  'Mike Tyson',
#  'English Spanish',
#  'Kaiju Australia',
#  'Nick Jackie Montreal Customs House',
#  'Ranger Gabe Walker',
#  'Nigerian Austria',
#  'Cory Christmas',
#  'Hill House',
#  'Rarity Equestria Land Applejack',
#  'Best Noriko Shinohara',
#  'Italian Gianfranco Rosi Rome',
#  'Iraq Lyn',
#  'Angelina',
#  'Computer Second Life',
#  'Indian Australia Indian',
#  'Kenneth Clark',
#  'Alfea',
#  'Andy Millman',
#  'Emily Calandrelli STEAM',
#  'Hughley Katherine Ryan',
#  'Iowa Ali Los Angeles',
#  'Pacific Ocean',
#  'Henry Ford II Enzo Ferrari',
#  'Young Dylan Hailey Ollie Battle Blading',
#  'Immortal Cadillac',
#  'American Greece',
#  'Héroes',
#  'Chennai',
#  'Aiko',
#  'Abah Emak',
#  'Set',
#  'Nick Vanessa Lachey',
#  'Cue Bartleby True',
#  'Teenage Nick Kroll Andrew Goldberg',
#  'Caution',
#  'Acapulco',
#  'Hogie Buenos Aires Cairo Hawaii Galapagos Islands',
#  'Madoka Kaname',
#  'Upshaws',
#  'Reese Witherspoon',
#  'Mexican Ayotzinapa Rural Teachers College Iguala',
#  'Nevada',
#  'Frenetic Kevin Hart Philadelphia',
#  'Mumbai',
#  'Lebanese',
#  'Beat Bugs Bug Factor Rocket Ship Park',
#  'Commander Sisko Deep Space Nine',
#  'India Islamic Muslim New York',
#  'Mark',
#  'Irish',
#  'Texas',
#  'Danish European',
#  'Dragon Warrior',
#  'Troobian Empire Earth',
#  'Great Dog Demon Three Swords Fang',
#  'Kretz France',
#  'Australian Outback',
#  'U.S. Korea',
#  'New Caledonia France Soane',
#  'Oceanside Wellness Center',
#  'LGBT',
#  'Louis',
#  'Ankara',
#  'Sleaze',
#  'Unemployed',
#  'Chhota Bheem Ramayana',
#  'Hit Frank Sheeran Bufalino Martin Scorsese',
#  'Bilbao',
#  'Los Angeles Chicano',
#  'Hell Los Angeles',
#  'Newlywed Iliza Shlesinger',
#  'Japanese Kim Korea New Women',
#  'Belle Epoque',
#  'Punjab British England',
#  'Frankie',
#  'Ahead',
#  'Sodor Thomas Steam Team',
#  'Katie Micah Micah',
#  'Canada Pakistan',
#  'Malibu Team Flounder International Beachmaster Competition',
#  'Miami',
#  'Astronomy Club',
#  'Frodo Sam Mordor Power Gimli Legolas Aragorn Merry Pippin',
#  'Earth United States',
#  'Jamie Foxx David Alan Grier',
#  'Johnnie To Hong Kong',
#  'Antoine',
#  'Umlazi Durban',
#  'Jesus',
#  'Super Megaforce Rangers',
#  'Earth Federation White Base Amuro Ray Zeon',
#  'Jimmy Saul Goodman',
#  'India Budapest',
#  'Char Hathaway Noa Earth Federation',
#  'Chilean Jani Dueñas',
#  'Larry Walmart America',
#  'Magic Mr. Harlo',
#  'Carlos Tevez Argentina Fuerte Apache',
#  'Kirk',
#  'Shirtless Bert Kreischer',
#  'Hulk Hogan Gawker Media',
#  'Virunga',
#  'Dutiful John Jake',
#  'British Chicago',
#  'Downton Abbey',
#  'Luxembourg',
#  'Jonathan Demme',
#  'Single',
#  'European',
#  'Ander Alexis',
#  'Enola Holmes',
#  'Kuwait',
#  'U.S. Indian America',
#  'Gaza',
#  'Wadi',
#  'Rachael Stirling Lee Radziwill',
#  'Sarah Moore',
#  'Delve Chaoshan',
#  'Sir Frank Williams',
#  'Worlds Altagracia',
#  'Frank Capra Germany Italy Japan America',
#  'Eager',
#  'Iowa Gilbert',
#  'New York Eddie Paris',
#  'Chinese African',
#  'José Aldo',
#  'NBA Michigan',
#  'Incredible Bongo Band Kool Herc',
#  'Arashi',
#  'Korean Japan',
#  'Test',
#  'Beirut',
#  'Queen Poppy Bridget Bergens Branch Snack Pack',
#  'Omar Mexico City',
#  'Sri Lanka',
#  'Newtown Connecticut',
#  'Mick Dundee Los Angeles American',
#  'Born India',
#  'American London',
#  'Young Moscow',
#  'Asian American',
#  'Bruce Lee Danny Chan',
#  'Ashraf Marwan Egyptian Israeli',
#  'Porta',
#  'Comedian Gabriel Iglesias San Jose California',
#  'Pedro Raúl Barcelona',
#  'Ash',
#  'Selly',
#  'Comedian Rory Scovel Atlanta',
#  'Part',
#  'Andrea Bocelli',
#  'Japan Makoto Edamura Laurent Thierry',
#  'Follow Julia Haart Elite World Group',
#  'Chris Rock',
#  'Boston Mr. Miyagi',
#  'Spaniard Argentina',
#  'Robles Americas Peru',
#  'Cosimo Medici',
#  'American Hong Kong',
#  'Kai Shuhei',
#  'Boston Globe Catholic Church',
#  'Nick',
#  'Kid Play',
#  'Universe Kevin Smith',
#  'Sarah Jakarta Zaenab Doel',
#  'Muslim Americans Texas',
#  'Tommy Pickles',
#  'America Chinese',
#  'Eid Ayvalık',
#  'Akash Sameer',
#  'Spain Mexico',
#  'Slick Sung',
#  'Ricky Bell Tampa Bay Buccaneers',
#  'Indian Shanghai',
#  'Maharashtra',
#  'Maddy Cole',
#  'Maury',
#  'Kidnapped',
#  'Fiza Mumbai',
#  'Gotham Garage',
#  'Metallica',
#  'Form Acid',
#  'Historian Ken Burns',
#  'Brittania',
#  'Samir Rani',
#  'Follow Santiago Artemis Buenos Aires',
#  'Malibu',
#  'American India',
#  'David Attenborough Johan Rockström Earth',
#  'Time',
#  'USA Gymnastics Larry Nassar USAG',
#  'Jamaica',
#  'Popular Roald Dahl Quentin Blake',
#  'Robert Boswell America',
#  'Jessica',
#  'Terry Bob',
#  'Turkey Aegean',
#  'Lotte',
#  'Christy Martin',
#  'Magnus Carlsen Norwegian',
#  'Daphne Mystery Machine Moonscar Island',
#  'Shi Won',
#  'Bruce Springsteen',
#  'Interior Benjamin',
#  'Dilan Milea Belgium',
#  'Brooms Town Robocar Poli Robotruck Roy',
#  'Egypt',
#  'Katt Williams America',
#  'Witness',
#  'Hedgehog Chaos Emeralds',
#  'U.S. Customs Border Protection',
#  'Ghost Club',
#  'Manson Family',
#  'Madagascar Valentine',
#  'Norm',
#  'Caucasian Arizona',
#  'Revenge',
#  'Denny',
#  'Samurai Power Rangers',
#  'Tech John McAfee',
#  'Motown',
#  'Syria',
#  'Quinglong Jinyiwei',
#  'LA England',
#  'Pop Mariah Carey Night Before Christmas',
#  'Inventor Flint Lockwood',
#  'Lima Peru',
#  'London Yehia',
#  'Omar Abdulrahman',
#  'American Harry Gordon Selfridge Londoners',
#  'Motu Patlu',
#  'Mikael',
#  'Pierce Brosnan James Bond Russian',
#  'Join Dan Jones Britain',
#  'Dylan',
#  'Writer Monty Don England',
#  'British Home Guard German',
#  'Bigfoot',
#  'U.S. Taiwanese',
#  'Actor Donald Faison',
#  'Ruby Maribel',
#  'Bye Bye Man',
#  'Indiana',
#  'Elle Noah',
#  'Jon Favreau',
#  'Zippy City',
#  'Naoki Higashida',
#  'China Hong Kong',
#  'Italian Saverio Raimondo Milan',
#  'Ramayana Lord Rama',
#  'Michael',
#  'Juan Manuel Fangio Formula One',
#  'Luminous Miami',
#  'Marine Gene Hackman US Marine Corps',
#  'Comedian Sam Jay',
#  'Help Jack',
#  'Nigerian Brazil',
#  'Antonio Sabato RVs',
#  'Author Stephen Elliott',
#  'Swedish David Batra',
#  'South African Paris',
#  'America Franklin Eleanor Roosevelt',
#  'Mexican American San Quentin',
#  'Andries Riphagen Dutch',
#  'Matrix',
#  'Fate Karachi Pakistan',
#  'Queen Elizabeth II Princess Margaret',
#  'Kara Danvers Superman Supergirl National City',
#  'Holly Tyler',
#  'British American',
#  'Indian Gujarat',
#  'Young Plunotaria',
#  'Rocko',
#  'Manhattan New York City',
#  'Prodigal Tumi',
#  'Spain Filipino',
#  'Deloris Geoff',
#  'Jiro Ono Tokyo',
#  'Omar',
#  'California Runaways',
#  'Nova Scotia',
#  'Ram',
#  'Black Plague',
#  'Huttsgalor Rescue Riders',
#  'Shuhei',
#  'Jamaica London',
#  'New York City Fran Lebowitz Martin Scorsese',
#  'Thrust Deena Sarah Fier',
#  'Li Lan',
#  'Kenya Barris',
#  'Jeremiah Tower American',
#  'U.S. Mint',
#  'Sweden',
#  'Brazil Pelé',
#  'Ollie Moon',
#  'Teenage Xue Ming',
#  'Ronnie Kray',
#  'Follow Lady Gaga',
#  'Ramen Masato Singapore',
#  'Hungary',
#  'Catherine',
#  'Indonesian',
#  'Catholics Mexico',
#  'Plucky Oscar',
#  'Young Nicolas Santa Claus',
#  'North Pole',
#  'Peru Brazil Colombia',
#  'Young Malaysia',
#  'Hasidic Jews',
#  'Tibetan',
#  'Evil Gargamel Smurfs',
#  'Abla Fahita',
#  'Bill America',
#  'Sakuragaoka High School London',
#  'Star Rohan',
#  'UFO',
#  'America Ponzi',
#  'Copenhagen Denmark',
#  'Mexican Los Angeles California',
#  'Ted Crawford',
#  'Rangers Angel Grove',
#  'Lincoln',
#  'Abu Dhabi Beirut',
#  'African American',
#  'France Kamal Beirut',
#  'Down',
#  'James Baldwin Medgar Evers Malcolm Martin Luther King',
#  'Evidence',
#  'Kannada',
#  'Teen Tina Falkenstein Castle',
#  'Set Grey City Love',
#  'Class',
#  'Eggy',
#  'Vesemir',
#  'NBA',
#  'Brown Education American',
#  'Paris Mr. Pickles EuroReptarland',
#  'Philippine Joseph',
#  'CARE',
#  'Habaek',
#  'Ryo',
#  'Gabriel',
#  'Asia Lee Jasper Liu',
#  'Chilean Pablo Neruda',
#  'Bridgerton London',
#  'Hector Maribel',
#  'Archival Mexican EZLN Luis Donaldo Colosio',
#  'Bombay',
#  'Africa',
#  'Spiced',
#  'Ink',
#  'Wang Dadong',
#  'Jeff Dunham Dallas Peanut Walter José Jalapeño Bubba Achmed American',
#  'Deshpande',
#  'Seoul',
#  'Tokyo Sirius',
#  'San Francisco Bruce Lee',
#  'High Kusuo',
#  'Tokyo Mexico',
#  'Comic Jim Gaffigan',
#  'Host Hugh Bonneville Jesus',
#  'Duri',
#  'Serbia',
#  'Greece Heron Zeus',
#  'Malaysia Tamilian',
#  'Māori Francis Kaiora Tipene Polynesian',
#  'Brazil',
#  'WWE',
#  'Ellen Brody Amity Island Caribbean',
#  'Argentine Aristarán',
#  'Israeli Manhattan',
#  'Ellen',
#  'Comedian Joaquín Reyes',
#  'Herman J. Mankiewicz Paul Hollywood Prue Leith',
#  'Dracula',
#  'Dutch',
#  'Nazis Auschwitz',
#  'NSFW Tim Miller David Fincher',
#  'Brooklyn Puerto Rican',
#  'Japanese',
#  'Comedian Tom Papa Staten Island New Jersey',
#  'William Kamkwamba Malawian',
#  'New Acha Iqbal',
#  'Ronnie Coleman',
#  'Yugo Wakfu',
#  'Rockland Ranch Utah',
#  'Carpet UFO Arif',
#  'Ash Goh',
#  'Ntozake Shange African American',
#  'Student',
#  'Buddha',
#  'Colombian Sanint Julián Arango',
#  'Western Missouri',
#  'Russian Cuban Miami Soviet Colombian',
#  'True Bartleby Dillydally Rainbow King',
#  'Taiwan Guo Xuehu',
#  'Grizzly Panda',
#  'Hollywood Dalton Trumbo',
#  'Comedian Jo Koy Hawaii',
#  'Liberdade São Paulo',
#  'Nigerian U.S.',
#  'Unhappy North Pole',
#  'Middle Nazuna Norimichi',
#  'Super Mario',
#  'Wimpy',
#  'Smoky Mountains',
#  'Asia Japan',
#  'Brooke Burns Beast',
#  'Dan',
#  'Skull Castle Flower',
#  'Journey Equestria',
#  'Yolanda',
#  'Tomato Christian',
#  'Charlie Wedemeyer Lou Gehrig',
#  'Anatolia',
#  'Amateur Athletic Union America',
#  'Rajesh Shankar',
#  'Madonna Dare',
#  'XXX U.S.',
#  'Jason Fox',
#  'Sade',
#  'Jassi',
#  'Swedish British',
#  'Pacific Army',
#  'Medium Yoh Asakura Shaman King',
#  'High Ayumi Zenko',
#  'British',
#  'Bheem Krishna',
#  'Between Jim Jefferies',
#  'Rainbow Kingdom Glummy Glooma',
#  'Moscow',
#  'Lavagirl',
#  'Quasar Sabers Galaxy Power Rangers Captain Mutiny',
#  'New York Roxanne',
#  'Carrie Miranda Samantha New York Abu Dhabi',
#  'Roberto Baggio Buddhism',
#  'Weeks',
#  'Nicholas Robinson Bristol England',
#  'Tired Rose Morgan',
#  'American Mount Fuji',
#  'Copper',
#  'Harold Kumar Harold Kumar',
#  'Siena Italy',
#  'American Australian',
#  'Caesar Napoleon Mussolini Hitler',
#  'Canada',
#  'Santa Claus North Pole',
#  'Tilikum',
#  'Jeffrey Epstein',
#  'Rescue Bots Academy',
#  'Armenian French',
#  'Elite Paralympic Games',
#  'Young Ulises',
#  'Supermodel Tyra Banks',
#  'Bheem Dragonpur',
#  'EXO SHINee Seoul',
#  'Portuguese American French',
#  'Spain U.S. Ashton',
#  'Harold Kumar White Castle',
#  'Comedian Daniel Sosa Trojan',
#  'Paper Moon Montana',
#  'Desperate Gunner',
#  'Miss Nigeria South Africa',
#  'Gruff Rene',
#  'Waitstill Sharp Martha',
#  'German Selma Bosnian War',
#  'Galvanax',
#  'British Gina Yashere San Francisco',
#  'Bella Edward',
#  'Shadyside Camp Nightwing',
#  'David Spade Fortune Feimster London Hughes Netflix',
#  'Grey Gardens Thin Blue Line',
#  'Seung Yeon',
#  'Comic Nate Bargatze',
#  'Set Lucian',
#  'Polish Rafał Pacześ Katarzyna Piasecka Warsaw Klub Hybrydy',
#  'Businesswoman Debra Newell John Meehan',
#  'Freed Motoko Aramaki',
#  'Prince Lee Cheong Joseon',
#  'Vir Das',
#  'Cross Academy',
#  'Oxford University',
#  'Lord Krishna Balaram Vrindavan',
#  'Kuala Lumpur Indonesia',
#  'Usain Bolt',
#  'Virgin Mary',
#  'Strange',
#  'Keen Dong Yilong',
#  'Shy Tara',
#  'National Assembly Environment Park Korea',
#  'Toyland Noddy',
#  'Laurie Joseph',
#  'Brazilian Afonso Padilha',
#  'Ben',
#  'Shy Aryan',
#  'Successful Beth',
#  'Anastasia Cardona',
#  'Botswana',
#  'Darndale Dublin',
#  'Harlem Ceaser',
#  'Latina Los Angeles',
#  'Tituss Burgess',
#  'Samantha',
#  'Circle',
#  'Didem',
#  'Daniel Sosa Mexican',
#  'Rick Ross CIA America',
#  'Cookie',
#  'Japanese Hong Kong Benny Ho Macau',
#  'Spenser Boston',
#  'Hideaki Sanma Jimmy',
#  'Halloween Frankie Stein',
#  'Argentine Lucas Lauriente',
#  'Veggie',
#  'British India',
#  'Shy Natsu',
#  'Argentina',
#  'Rick Cristy',
#  'City Joy',
#  'Barcelona',
#  'Jessica Lall',
#  'Jake Armstrong',
#  'Secret Service John',
#  'Chhota Bheem Russia',
#  'Janeiro Rocket',
#  'Ryuko Matoi',
#  'Korea Seoul',
#  'Runaway Harry',
#  'Brandon Beckett',
#  'Harry Dean Stanton Montana Fishtail Basin Ranch',
#  'Masire Johannesburg',
#  'Abducted Lebanese Civil War Ramez',
#  'Busan Japan',
#  'Forty',
#  'Bodybuilder Calum',
#  'Trained Vandana Hart',
#  'Jonas',
#  'Between Oasis',
#  'Zoya Akhtar Anurag Kashyap Dibakar Banerjee Karan Johar',
#  'Joshua Wong Hong Kong China',
#  'Chhota Bheem China',
#  'Rookie Jeffrey Cole',
#  'Indian Prince Arjun Sanskrit Mahabharata',
#  'Ferrari Porsche',
#  'Texas Rangers Bonnie Clyde',
#  'Son Sam Maury Terry',
#  'Marc Maron New York Chinese',
#  'American Barbecue',
#  'Sleepless',
#  'Cape Mercy',
#  'Shyam',
#  'Shaolin',
#  'U.S.',
#  'Eager Ian',
#  'Eddie',
#  'Host Leon Logothetis',
#  'OCD Down Syndrome',
#  'Griffith Guts Band Hawk',
#  'Hole',
#  'Buckle Florida',
#  'Max Sell Drugs Online',
#  'Oscar Grant San Francisco New Year',
#  'Kudret',
#  'Artiwara Kongmalai Thailand',
#  'OCD',
#  'Power Rangers Earth',
#  'Laura Palmer',
#  'Band Hawk Guts',
#  'Libertine Amanda',
#  'Banaras',
#  'American Halston',
#  'Kuala Lumpur Diana',
#  'Garfield',
#  'Google Earth',
#  'Fire Water Earth',
#  'African American Kevin Hart',
#  'ChuChu',
#  'Kirlian Argentina',
#  'Indian Sanjay Dutt',
#  'Aziz Ansari Parks',
#  'Pablo Escobar',
#  'India Analysis Wing Pakistan',
#  'Mauritius',
#  'Basque Country',
#  'Mongol Yunus Emre Ottoman Empire',
#  'Bubbles Julian Ricky Canadian American',
#  'Clóvis Lohane',
#  'Liz',
#  'Mexico US',
#  'Mexican Franco Escamilla',
#  'Chaos',
#  'Bruce Lee Shaolin',
#  'Husband',
#  'Loner Guts Griffith',
#  'French Dominique',
#  'New Yorker',
#  'McDonald',
#  'Luther Krank Christmas Frosty',
#  'Hitler Nazis Britain Polish Royal Air Force',
#  'New York Max Snowball Gidget',
#  'Chelsea Handler',
#  'Eric Taylor Texas',
#  'Joan Didion Griffin Dunne',
#  'Nazi Germany',
#  'China Kuomintang',
#  'Waterloo',
#  'Gwangju South Korea',
#  'Tiny Shopkins Small Mart Shopville',
#  'Mumbai Shoaib Khan',
#  'Mecnun Leyla',
#  'NBA Canadian',
#  'Cassini Saturn',
#  'Syrian',
#  'Cole Evans Wild Force Power Rangers',
#  'Nevenka Fernández Spain',
#  'Six',
#  'Glock Chicago Kirkuk',
#  'Mayuri Seiretei',
#  'Fievel Russian America',
#  'Hollywood',
#  'Khon Thai',
#  'Zany Willy Wonka',
#  'Gwyneth Paltrow',
#  'CIA Colombian',
#  'Hip Londoner Will',
#  'Fighter',
#  'Dark Alina Starkov',
#  'Buckle',
#  'Georgian',
#  'Arsenal',
#  'Diwali',
#  'United Nations',
#  'Lazarus',
#  'Jack Whitehall London West End',
#  'CIA Eastern European',
#  'Gloria Allred',
#  'Pac Berry Betrayus Santa Pac',
#  'Cecil Hotel Elisa Lam',
#  'Comedian Ralphie',
#  'Trolls Messina',
#  'Alaska',
#  'Viorel',
#  'Miranda Sings Colleen Ballinger',
#  'Lina',
#  'FBI Jack Crawford',
#  'Henry Lee Lucas',
#  'Princess Diana Charles Althorp House Spencer',
#  'High Yuta',
#  'John Mulaney Motown',
#  'France West Jimmy',
#  'Comedian Billy Eichner New York',
#  'George',
#  'Dirk Diggler',
#  'Macau',
#  'Death',
#  'Rebirth',
#  'Colombian Andrés López López',
#  'Spanish Laura',
#  'Incredible',
#  'Joon Park Los Angeles',
#  'Chris NFL',
#  'Skeeter',
#  'Vinny Pazienza',
#  'Glimpse',
#  'Comedian Ben Gleib',
#  'Chewbacca',
#  'Thakur Avadh',
#  'Nadiya Hussain',
#  'Spike Jonze Aziz Ansari',
#  'Toronto',
#  'Indonesian American',
#  'Miles Daly Elmore Leonard',
#  'Kate',
#  'Brooke',
#  'Paul Cézanne',
#  'Robert Rodriguez',
#  'Uruguayan',
#  'Between São Paulo Emicida Black',
#  'Scandinavian',
#  'Torn Doel',
#  'Vince Kath James',
#  'Frasier Crane',
#  'Nezha',
#  'Domestic Timothy McVeigh Oklahoma City',
#  'Psychlos Earth',
#  'Apostle Matthew Jesus',
#  'French Alps',
#  'Rich Froning CrossFit Games',
#  'Drug Punjab',
#  'U.S. Hezbollah',
#  'BFFs',
#  'New Orleans',
#  'Sebastián',
#  'Kaylie Konrad',
#  'Brazil New York',
#  'Kaz Kaan Neo Yokio',
#  'Comedian Jim Gaffigan Hot Pockets Catholicism',
#  'Vincenzo Muccioli',
#  'Director Sergio Leone Jewish New York City',
#  'Veronica Victor',
#  'Shortsighted Mr. Magoo Justin',
#  'Bob Weir Jerry Garcia',
#  'Kongpob Arthit',
#  'Argentina Tango',
#  'Photographer Sam Jones',
#  'Lucis Niflheim',
#  'Parton MusiCares Person',
#  'Amid Sodor Thomas',
#  'Elastigirl',
#  'Alhaja Eniola Salami',
#  'Concert Uruguayan Natalia Oreiro Russia',
#  'Middle Kai',
#  'French Nekfeu',
#  'Mexican Manuel Buendía',
#  'Equestria Canterlot High',
#  'Historian Bettany Hughes Karl Marx Friedrich Nietzsche Sigmund Freud',
#  'Naruto Uzumaki',
#  'Gab',
#  'U.S. Yugoslavia',
#  'Gorgeous Albanian Rezeta Mexico City',
#  'Power Rangers Dillon',
#  'Maddie',
#  'Western Lucky Abigail',
#  'Crusades Paris',
#  'New Cenk',
#  'Sinners Ichigo',
#  'Jeff Dunham America',
#  'Julia Quinn',
#  'Reality',
#  'Croc Shifu',
#  'AIDS Ron Woodroof',
#  'Ashar',
#  'Alain Delambre',
#  'Club Argentina',
#  'Asgard',
#  'Iconic Barbra Streisand Miami Broadway',
#  'British Empire Africa Shaka Zulu Nation',
#  'London Kenny Kenny',
#  'Pocoyo',
#  'New York City Barbie Malibu Barbie Brooklyn',
#  ...]
